# %%
import matplotlib.pyplot as plt
import numpy as np
from Linear_Regression_1D_GD import Linear_Regression

# %%
x = np.arange(1,101,5)
y = x*3

# %%
algo = Linear_Regression()
algo
# Out:
# class Linear_Regression_1D_GD.Linear_Regression<niterations = 1000, alpha = 1, stoppage = 0.001>

# %%
algo.fit(x, y)

# %%
algo.score(x, y)
# Out:
# 0.9999995461000952

# %%
algo.coef_
# Out:
# 3.000300852329633

# %%
algo.intercept_
# Out:
# 0.043032445812309535

# %%
algo.cost(x, y)
# Out:
# 0.0033957386626507027

# %%
y_pred = algo.predict(x)

# %%
plt.plot(x, y_pred)
plt.scatter(x, y)
plt.show()
